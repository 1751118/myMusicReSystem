# %% [markdown]
# #### 1、定义通用函数计时

# %%
import time
import math
import random
import pandas as pd

# 函数计时
def timmer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        stop_time = time.time()
        print('Func %s, run time:%s' % (func.__name__, stop_time - start_time))
        return res
    return wrapper

# %% [markdown]
# #### 2、加载数据集

# %%
class Dataset():
    def __init__(self, algo = 'UserCF'):
        self.project_path = './'
        self.data_path = 'Train_Test_Splits/Context/train.csv'
        self.data = {}
        if algo in ['UserCF', 'ItemCF', 'MostPopular', 'Random']:
            self.data = self.loadUserCFData()
        print(self.data.shape)
    
    @timmer
    def loadUserCFData(self):
        data = pd.read_csv(self.project_path + self.data_path)
        data = data[['user_id', 'track_id']]
        return data 
    
    @timmer
    def splitData(self, M, k, seed = 1):
        '''
        M: 划分的数目，最后取M折平均
        k: 本次是第k次划分
        '''
        data = []
        for index, row in self.data.iterrows():
            data.append((row['user_id'], row['track_id']))
        
        def convert_dict(data):
            data_dict = {}
            for user, item in data:
                if user not in data_dict:
                    data_dict[user] = set()
                data_dict[user].add(item)
            data_dict = {k: list(data_dict[k]) for k in data_dict}
            return data_dict  # {user1:(s1, s2, s3......)}
        
        data = convert_dict(data)
        train, test = {}, {}
        for user, items in data.items():
            if len(items) < 5: continue
            
            if user not in train:
                train[user], test[user] = set(), set()
                
            # 将元素随机打散
            random.shuffle(items)
            
            # 分割训练集测试集
            split_point = int(len(items) * 0.75)
            train[user] = items[ :split_point]
            test[user] = items[split_point: ]
                
        return train, test

# %% [markdown]
# #### 3、算法
# - 随机算法Random
# - 最热门MostPopular
# - UserCF
# - ItemCF

# %%
# 1.随机推荐
def Random(train, K, N):
    ''' 
    K，可忽略
    N，超参数，设置的TopN推荐物品数
    return: GetRecommendation, 推荐接口函数
    '''
    items = {}
    for user in train:
        for item in train[user]:
            items[item] = 1
    
    def GetRecommendation(user):
        #筛选掉用户已经评过分的物品
        user_items = set(train[user])
        rec_items = {k: items[k] for k in items if k not in user_items} 
        
        #推荐不在该用户列表中的物品中的随机N个
        rec_items = list(rec_items.items()) 
        random.shuffle(rec_items)
        return rec_items[:N]
    
    return GetRecommendation


#最流行推荐
def MostPopular(train, K, N):
    ''' 
    K，可忽略
    N，超参数，设置的TopN推荐物品数
    return: GetRecommendation, 推荐接口函数
    '''
    items = {}
    for user in train:
        for item in train[user]:
            if item not in items:
                items[item] = 0
            items[item] += 1
    def GetRecommendation(user):
        user_items = set(train[user])
        rec_items = {k:items[k] for k in items if k not in user_items}
        rec_items = list(sorted(rec_items.items(), key = lambda x:x[1], reverse=True)) #按物品点击量推荐前N项
        return rec_items[0:N]
    
    return GetRecommendation

# 3. 基于用户余弦相似度的推荐
def UserCF(train, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似用户数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    '''
    # 计算item->user的倒排索引
    item_users = {}
    for user in train:
        for item in train[user]:
            if item not in item_users:
                item_users[item] = set()
            item_users[item].add(user)
    
    # 计算用户相似度矩阵
    sim = {}
    num = {}
    for item in item_users:
        users = item_users[item]
        for u in users:
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for v in users:
                if u == v: continue
                if v not in sim[u]:
                    sim[u][v] = 0
                sim[u][v] += 1
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
    
    # 按照相似度排序
    sorted_user_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set(train[user])
        for u, _ in sorted_user_sim[user][:K]:
            for item in train[u]:
                # 要去掉用户见过的
                if item not in seen_items:
                    if item not in items:
                        items[item] = 0
                    items[item] += sim[user][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    return GetRecommendation

def UserIIF(train, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似用户数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    '''
    # 计算item->user的倒排索引
    item_users = {}
    for user in train:
        for item in train[user]:
            if item not in item_users:
                item_users[item] = set()
            item_users[item].add(user)
    
    # 计算用户相似度矩阵
    sim = {}
    num = {}
    for item in item_users:
        users = item_users[item]
        for u in users:
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for v in users:
                if u == v: continue
                if v not in sim[u]:
                    sim[u][v] = 0
                sim[u][v] += 1 / math.log(1 + len(users))
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
    
    # 按照相似度排序
    sorted_user_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set(train[user])
        for u, _ in sorted_user_sim[user][:K]:
            for item in train[u]:
                # 要去掉用户见过的
                if item not in seen_items:
                    if item not in items:
                        items[item] = 0
                    items[item] += sim[user][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    return GetRecommendation

# %% [markdown]
# #### 4、测评
# 指标包括：
# - Precision
# - Recall
# - Coverage
# - Popularity

# %%
class Metric():
    def __init__(self, train, test, GetRecommendation):
        ''' 
        GetRecommendation: 为某个用户获取推荐列表的接口
        '''
        self.train = train
        self.test = test
        self.GetRecommendation = GetRecommendation
        self.recs = self.getRec()
    
    # 为test中的每个用户进行推荐
    def getRec(self):
        recs = {}
        for user in self.test:
            rank = self.GetRecommendation(user)
            recs[user] = rank
        return recs
    
    # 精确率
    def precision(self):
        n_precision = 0
        hit = 0
        for user in self.test:
            test_items = set(self.test[user])
            rank = self.recs[user]
            for item, score in rank:
                if item in test_items:
                    hit += 1
            n_precision += len(rank)
        return round(hit / n_precision * 100, 2)
    
    #召回率
    def recall(self):
        n_recall = 0
        hit = 0
        for user in self.test:
            test_items = set(self.test[user])
            rank = self.recs[user]
            for item, score in rank:
                if item in test_items:
                    hit += 1
            n_recall += len(test_items)
        return round(hit / n_recall * 100, 2)
    
    # 覆盖率
    def coverage(self):
        all_item, recom_item = set(), set()
        for user in self.test:
            for item in self.train[user]:
                all_item.add(item)
            rank = self.recs[user]
            for item, score in rank:
                recom_item.add(item)
        return round(len(recom_item) / len(all_item) * 100, 2)
    
    # 流行度，这里用物品在训练集中出现的次数作为流行度，新颖度与流行度成反比
    def popularity(self):
        item_pop = {}
        for user in self.train:
            for item in self.train[user]:
                if item not in item_pop:
                    item_pop[item] = 0
                item_pop[item] += 1
        pop, num = 0, 0
        for user in self.test:
            rank = self.recs[user]
            for item, score in rank:
                #取对数防止因长尾问题带来的被流行物品所主导的现象
                pop += math.log(1 + item_pop[item])
                num += 1
        return round(pop / num, 6)
    
    #所有指标
    def eval(self):
        metric = {'Precision': self.precision(),
                  'Recall': self.recall(),
                  'Coverage': self.coverage(),
                  'Popularity': self.popularity()}
        print('Metric:', metric)
        return metric

# %% [markdown]
# #### 5、实验

# %%
class Experiment():
    def __init__(self, M, K, N, rt = 'UserCF'):
        ''' 
        进行M次实验
        K，TopK相似用户的个数
        N，TopN推荐物品的个数
        fp，数据路径
        rt，推荐算法类型
        '''
        self.M = M
        self.K = K
        self.N = N
        self.rt = rt
        self.alg = {'Random': Random, 'MostPopular': MostPopular,
                    'UserCF': UserCF, 'UserIIF':UserIIF}
    
    # 单次实验
    @timmer
    def worker(self, train, test):
        getRecs = self.alg[self.rt](train, self.K, self.N)
        metric = Metric(train, test, getRecs)
        return metric.eval()
    
    # 多次平均实验
    @timmer
    def run(self):
        import json
        metrics = {'Precision': 0, 'Recall': 0,
                   'Coverage': 0, 'Popularity': 0}
        dataset = Dataset(self.rt)
        for ii in range(self.M):
            train, test = dataset.splitData(self.M, ii)
            print("Experiment:{}".format(ii + 1))
            metric = self.worker(train, test)
            metrics = {k: metrics[k] + metric[k] for k in metrics}
        metrics = {k: metrics[k] / self.M for k in metrics}
        print('Average Result (M={}, K={}, N={}):{}'.format(self.M, self.K, self.N, metrics))

# %%
# 1、Random算法测试
M, N = 8, 10
K = 0
random_exp = Experiment(M, K, N, rt = 'Random')
random_exp.run()
# Out:
# Func loadUserCFData, run time:0.4484426975250244
# (257012, 2)
# Func splitData, run time:6.373152494430542
# Experiment:1
# Metric: {'Precision': 0.03, 'Recall': 0.02, 'Coverage': 33.99, 'Popularity': 0.848581}
# Func worker, run time:5.331028699874878
# Func splitData, run time:6.3074119091033936
# Experiment:2
# Metric: {'Precision': 0.04, 'Recall': 0.04, 'Coverage': 34.38, 'Popularity': 0.845732}
# Func worker, run time:5.258934497833252
# Func splitData, run time:6.362462520599365
# Experiment:3
# Metric: {'Precision': 0.03, 'Recall': 0.02, 'Coverage': 34.36, 'Popularity': 0.845678}
# Func worker, run time:5.154260635375977
# Func splitData, run time:6.269952774047852
# Experiment:4
# Metric: {'Precision': 0.09, 'Recall': 0.07, 'Coverage': 34.48, 'Popularity': 0.849321}
# Func worker, run time:5.206905841827393
# Func splitData, run time:6.36468505859375
# Experiment:5
# Metric: {'Precision': 0.01, 'Recall': 0.01, 'Coverage': 34.22, 'Popularity': 0.853044}
# Func worker, run time:5.266417980194092
# Func splitData, run time:6.298834800720215
# Experiment:6
# Metric: {'Precision': 0.04, 'Recall': 0.04, 'Coverage': 34.19, 'Popularity': 0.841066}
# Func worker, run time:5.21891975402832
# Func splitData, run time:6.415503740310669
# Experiment:7
# Metric: {'Precision': 0.01, 'Recall': 0.01, 'Coverage': 34.13, 'Popularity': 0.845398}
# Func worker, run time:5.393731594085693
# Func splitData, run time:6.461518287658691
# Experiment:8
# Metric: {'Precision': 0.01, 'Recall': 0.01, 'Coverage': 34.13, 'Popularity': 0.848169}
# Func worker, run time:5.152619361877441
# Average Result (M=8, K=0, N=10):{'Precision': 0.0325, 'Recall': 0.027500000000000007, 'Coverage': 34.235, 'Popularity': 0.847123625}
# Func run, run time:93.29387044906616

# %%
# 2、MostPopular算法测试
M, N = 8, 10
K = 0
random_exp = Experiment(M, K, N, rt = 'MostPopular')
random_exp.run()
# Out:
# Func loadUserCFData, run time:0.4459960460662842
# (257012, 2)
# Func splitData, run time:6.3159706592559814
# Experiment:1
# Metric: {'Precision': 0.83, 'Recall': 0.68, 'Coverage': 0.15, 'Popularity': 2.793197}
# Func worker, run time:2.5765249729156494
# Func splitData, run time:6.311458349227905
# Experiment:2
# Metric: {'Precision': 0.83, 'Recall': 0.68, 'Coverage': 0.15, 'Popularity': 2.721042}
# Func worker, run time:2.572037935256958
# Func splitData, run time:6.339651107788086
# Experiment:3
# Metric: {'Precision': 0.92, 'Recall': 0.75, 'Coverage': 0.17, 'Popularity': 2.757758}
# Func worker, run time:2.5693230628967285
# Func splitData, run time:6.270670413970947
# Experiment:4
# Metric: {'Precision': 0.93, 'Recall': 0.76, 'Coverage': 0.17, 'Popularity': 2.748461}
# Func worker, run time:2.510092258453369
# Func splitData, run time:6.258063554763794
# Experiment:5
# Metric: {'Precision': 0.66, 'Recall': 0.54, 'Coverage': 0.17, 'Popularity': 2.826522}
# Func worker, run time:2.849672317504883
# Func splitData, run time:6.332075834274292
# Experiment:6
# Metric: {'Precision': 0.72, 'Recall': 0.59, 'Coverage': 0.15, 'Popularity': 2.818287}
# Func worker, run time:2.6753108501434326
# Func splitData, run time:6.3860414028167725
# Experiment:7
# Metric: {'Precision': 0.87, 'Recall': 0.71, 'Coverage': 0.18, 'Popularity': 2.780047}
# Func worker, run time:2.6086971759796143
# Func splitData, run time:6.384267091751099
# Experiment:8
# Metric: {'Precision': 0.69, 'Recall': 0.57, 'Coverage': 0.17, 'Popularity': 2.811742}
# Func worker, run time:2.585625410079956
# Average Result (M=8, K=0, N=10):{'Precision': 0.8062499999999999, 'Recall': 0.66, 'Coverage': 0.16375, 'Popularity': 2.782132}
# Func run, run time:71.99851703643799
