# %% [markdown]
# #### 1、定义通用函数计时

# %%
import time
import math
import random
import pandas as pd

# 函数计时
def timmer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        stop_time = time.time()
        print('Func %s, run time:%s' % (func.__name__, stop_time - start_time))
        return res
    return wrapper

# %% [markdown]
# #### 2、加载数据集

# %%
class Dataset():
    def __init__(self, algo = 'UserCF'):
        self.project_path = './'
        self.train_path = 'Train_Test_Splits/Context/train.csv'
        self.test_path = 'Train_Test_Splits/Context/test.csv'
        self.train = {}
        self.test = {}
        if algo in ['UserCF', 'ItemCF', 'MostPopular', 'Random']:
            self.train, self.test = self.loadUserCFData()
    
    @timmer
    def loadUserCFData(self):
        train = pd.read_csv(self.project_path + self.train_path)
        test = pd.read_csv(self.project_path + self.test_path)
        train = train[['user_id', 'track_id']]
        test = test[['user_id', 'track_id']]
        return train, test
    
    @timmer
    def splitData(self, M, k, seed = 1):
        '''
        M: 划分的数目，最后取M折平均
        k: 本次是第k次划分
        '''
        self.train = self.train.sort_values(by=['user_id'])
        self.test = self.test.sort_values(by=['user_id'])
        
        train, test = [], []
        for index, row in self.train.iterrows():
            train.append((row['user_id'], row['track_id']))
        for index, row in self.test.iterrows():
            test.append((row['user_id'], row['track_id']))
        
        def convert_dict(data):
            data_dict = {}
            for user, item in data:
                if user not in data_dict:
                    data_dict[user] = set()
                data_dict[user].add(item)
            data_dict = {k: list(data_dict[k]) for k in data_dict}
            return data_dict  # {user1:(s1, s2, s3......)}
        
        return convert_dict(train), convert_dict(test)

# %% [markdown]
# #### 3、算法
# - 随机算法Random
# - 最热门MostPopular
# - UserCF
# - ItemCF

# %%
# 1.随机推荐
def Random(train, test, K, N):
    ''' 
    K，可忽略
    N，超参数，设置的TopN推荐物品数
    return: GetRecommendation, 推荐接口函数
    '''
    
    # 获取曲库中所有歌曲
    items = {}
    for user in train:
        for item in train[user]:
            items[item] = 1
    for user in test:
        for item in test[user]:
            items[item] = 1
    
    def GetRecommendation(user):
        #筛选掉用户已经评过分的物品
        user_items = set()
        if user in train:
            user_items = train[user]
        rec_items = {k: items[k] for k in items if k not in user_items} 
        
        #推荐不在该用户列表中的物品中的随机N个
        rec_items = list(rec_items.items()) 
        random.shuffle(rec_items)
        return rec_items[:N]
    
    return GetRecommendation


#最流行推荐
def MostPopular(train, test, K, N):
    ''' 
    K，可忽略
    N，超参数，设置的TopN推荐物品数
    return: GetRecommendation, 推荐接口函数
    '''
    items = {}
    for user in train:
        for item in train[user]:
            if item not in items:
                items[item] = 0
            items[item] += 1
    def GetRecommendation(user):
        user_items = set()
        if user in train:
            user_items = train[user]
            
        rec_items = {k:items[k] for k in items if k not in user_items}
        rec_items = list(sorted(rec_items.items(), key = lambda x:x[1], reverse=True)) #按物品点击量推荐前N项
        return rec_items[0:N]
    
    return GetRecommendation

# 3. 基于用户余弦相似度的推荐
def UserCF(train, test, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似用户数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    '''
    # 计算item->user的倒排索引
    item_users = {}
    for user in train:
        for item in train[user]:
            if item not in item_users:
                item_users[item] = set()
            item_users[item].add(user)
    
    # 计算用户相似度矩阵
    sim = {}
    num = {}
    for item in item_users:
        users = item_users[item]
        for u in users:
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for v in users:
                if u == v: continue
                if v not in sim[u]:
                    sim[u][v] = 0
                sim[u][v] += 1
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
    
    # 按照相似度排序
    sorted_user_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set()
        if user in train:
            seen_items = train[user]
        for u, _ in sorted_user_sim[user][:K]:
            for item in train[u]:
                # 要去掉用户见过的
                if item not in seen_items:
                    if item not in items:
                        items[item] = 0
                    items[item] += sim[user][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    return GetRecommendation
# 4、惩罚热门音乐的改进
def UserIIF(train, test, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似用户数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    '''
    # 计算item->user的倒排索引
    item_users = {}
    for user in train:
        for item in train[user]:
            if item not in item_users:
                item_users[item] = set()
            item_users[item].add(user)
    
    # 计算用户相似度矩阵
    sim = {}
    num = {}
    for item in item_users:
        users = item_users[item]
        for u in users:
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for v in users:
                if u == v: continue
                if v not in sim[u]:
                    sim[u][v] = 0
                sim[u][v] += 1 / math.log(1 + len(users))
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
    
    # 按照相似度排序
    sorted_user_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set(train[user])
        for u, _ in sorted_user_sim[user][:K]:
            for item in train[u]:
                # 要去掉用户见过的
                if item not in seen_items:
                    if item not in items:
                        items[item] = 0
                    items[item] += sim[user][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    return GetRecommendation
    
    
# 5. 基于物品余弦相似度的推荐
def ItemCF(train, test, K, N):
    '''
    :params: train, 训练数据集
    :params: K, 超参数，设置取TopK相似物品数目
    :params: N, 超参数，设置取TopN推荐物品数目
    :return: GetRecommendation, 推荐接口函数
    '''
    # 计算物品相似度矩阵
    sim = {}
    num = {}
    for user in train:
        items = train[user]
        for i in range(len(items)):
            u = items[i]
            if u not in num:
                num[u] = 0
            num[u] += 1
            if u not in sim:
                sim[u] = {}
            for j in range(len(items)):
                if j == i: continue
                v = items[j]
                if v not in sim[u]:
                    sim[u][v] = 0
                sim[u][v] += 1
    for u in sim:
        for v in sim[u]:
            sim[u][v] /= math.sqrt(num[u] * num[v])
    
    # 按照相似度排序
    sorted_item_sim = {k: list(sorted(v.items(), \
                               key=lambda x: x[1], reverse=True)) \
                       for k, v in sim.items()}
    
    # 获取接口函数
    def GetRecommendation(user):
        items = {}
        seen_items = set()
        if user in train:
            seen_items = train[user]
        for item in train[user]:
            if item not in sorted_item_sim: continue
            for u, _ in sorted_item_sim[item][:K]:
                if u not in seen_items:
                    if u not in items:
                        items[u] = 0
                    items[u] += sim[item][u]
        recs = list(sorted(items.items(), key=lambda x: x[1], reverse=True))[:N]
        return recs
    
    return GetRecommendation

# %% [markdown]
# #### 4、测评
# 指标包括：
# - Precision
# - Recall
# - Coverage
# - Popularity

# %%
class Metric():
    def __init__(self, train, test, GetRecommendation):
        ''' 
        GetRecommendation: 为某个用户获取推荐列表的接口
        '''
        self.train = train
        self.test = test
        self.GetRecommendation = GetRecommendation
        self.recs = self.getRec()
    
    # 为test中的每个用户进行推荐
    def getRec(self):
        recs = {}
        for user in self.test:
            # 这里主要是过滤掉协同推荐中无历史行为记录的用户
            if user not in self.train:
                continue
            rank = self.GetRecommendation(user)
            recs[user] = rank
        return recs
    
    # 精确率
    def precision(self):
        n_precision = 0
        hit = 0
        for user in self.test:
            
            # 协同过滤需要过滤掉没有历史行为的用户，其他算法可不执行
            if user not in self.train:
                continue
            
            test_items = set(self.test[user])
            rank = self.recs[user]
            for item, score in rank:
                if item in test_items:
                    hit += 1
            n_precision += len(rank)

        return round(hit / n_precision * 100, 2)
    
    #召回率
    def recall(self):
        n_recall = 0
        hit = 0
        for user in self.test:
            
            # 协同过滤需要过滤掉没有历史行为的用户
            if user not in self.train:
                continue
            
            test_items = set(self.test[user])
            rank = self.recs[user]
            for item, score in rank:
                if item in test_items:
                    hit += 1
            n_recall += len(test_items)

        return round(hit / n_recall * 100, 2)
    
    # 覆盖率
    def coverage(self):
        all_item, recom_item = set(), set()
        for user in self.test:
            
            # 协同过滤需要过滤掉没有历史行为的用户
            if user not in self.train:
                continue
            
            if user in self.train:
                for item in self.train[user]:
                    all_item.add(item)
            rank = self.recs[user]
            for item, score in rank:
                recom_item.add(item)

        return round(len(recom_item) / len(all_item) * 100, 2)
    
    # 流行度，这里用物品在训练集中出现的次数作为流行度，新颖度与流行度成反比
    def popularity(self):
        item_pop = {}
        for user in self.train:
            for item in self.train[user]:
                if item not in item_pop:
                    item_pop[item] = 0
                item_pop[item] += 1
        pop, num = 0, 0
        for user in self.test:
            
            # 协同过滤需要过滤掉没有历史行为的用户
            if user not in self.train:
                continue
            
            rank = self.recs[user]
            for item, score in rank:
                #取对数防止因长尾问题带来的被流行物品所主导的现象
                if item not in item_pop: continue
                
                pop += math.log(1 + item_pop[item])
                num += 1

        return round(pop / num, 6) # 公式应该是 测试集中的所有歌曲，在训练集中出现的次数为 ni  sum(log(ni + 1)) / |rank|
    
    #所有指标
    def eval(self):
        metric = {'Precision': self.precision(),
                  'Recall': self.recall(),
                  'Coverage': self.coverage(),
                  'Popularity': self.popularity()}
        print('Metric:', metric)
        return metric

# %% [markdown]
# #### 5、实验

# %%
class Experiment():
    def __init__(self, M, K, N, rt = 'UserCF'):
        ''' 
        进行M次实验
        K，TopK相似用户的个数
        N，TopN推荐物品的个数
        fp，数据路径
        rt，推荐算法类型
        '''
        self.M = M
        self.K = K
        self.N = N
        self.rt = rt
        self.alg = {'Random': Random, 'MostPopular': MostPopular,
                    'UserCF': UserCF, 'UserIIF':UserIIF,
                    'ItemCF': ItemCF}
        self.recs = {} # 这里想要定义一个函数
    
    # 单次实验
    @timmer
    def worker(self, train, test):
        getRecs = self.alg[self.rt](train, test, self.K, self.N)
        self.recs = getRecs
        metric = Metric(train, test, getRecs)
        return metric.eval()
    
    # 多次平均实验
    @timmer
    def run(self):
        import json
        metrics = {'Precision': 0, 'Recall': 0,
                   'Coverage': 0, 'Popularity': 0}
        dataset = Dataset(self.rt)
        for ii in range(self.M):
            train, test = dataset.splitData(self.M, ii)
            
            # with open('train.json', 'w') as f:
            #     json.dump(train, f, indent=4)
            # with open('test.json', 'w') as f:
            #     json.dump(test, f, indent=4)
                
            print("Experiment:{}".format(ii + 1))
            metric = self.worker(train, test)
            metrics = {k: metrics[k] + metric[k] for k in metrics}
        metrics = {k: metrics[k] / self.M for k in metrics}
        print('Average Result (M={}, K={}, N={}):{}'.format(self.M, self.K, self.N, metrics))
    
    @timmer
    def getRecs(self, user):
        return [items[0] for items in self.recs(user)]

# %%
# 1、Random算法测试
M, N = 10, 10
K = 0
random_exp = Experiment(M, K, N, rt = 'Random')
random_exp.run()
# Out:
# Func loadUserCFData, run time:0.6508347988128662
# Func splitData, run time:9.256670713424683
# Experiment:1
# Metric: {'Precision': 0.07, 'Recall': 0.03, 'Coverage': 38.4, 'Popularity': 0.905073}
# Func worker, run time:17.107415437698364
# Func splitData, run time:9.33690881729126
# Experiment:2
# Metric: {'Precision': 0.04, 'Recall': 0.02, 'Coverage': 38.39, 'Popularity': 0.889715}
# Func worker, run time:16.277704000473022
# Func splitData, run time:9.404733657836914
# Experiment:3
# Metric: {'Precision': 0.03, 'Recall': 0.01, 'Coverage': 38.21, 'Popularity': 0.890806}
# Func worker, run time:15.811793088912964
# Func splitData, run time:9.353389024734497
# Experiment:4
# Metric: {'Precision': 0.01, 'Recall': 0.01, 'Coverage': 38.41, 'Popularity': 0.892845}
# Func worker, run time:16.214905977249146
# Func splitData, run time:9.561307907104492
# Experiment:5
# Metric: {'Precision': 0.01, 'Recall': 0.01, 'Coverage': 38.18, 'Popularity': 0.899176}
# Func worker, run time:15.731945276260376
# Func splitData, run time:9.370469331741333
# Experiment:6
# Metric: {'Precision': 0.04, 'Recall': 0.02, 'Coverage': 38.05, 'Popularity': 0.888603}
# Func worker, run time:15.587330341339111
# Func splitData, run time:9.508489847183228
# Experiment:7
# Metric: {'Precision': 0.03, 'Recall': 0.01, 'Coverage': 38.27, 'Popularity': 0.885841}
# Func worker, run time:15.528252840042114
# Func splitData, run time:9.27440094947815
# Experiment:8
# Metric: {'Precision': 0.06, 'Recall': 0.03, 'Coverage': 38.21, 'Popularity': 0.89493}
# Func worker, run time:15.1172776222229
# Func splitData, run time:9.274969577789307
# Experiment:9
# Metric: {'Precision': 0.04, 'Recall': 0.02, 'Coverage': 38.43, 'Popularity': 0.893093}
# Func worker, run time:15.188222169876099
# Func splitData, run time:9.28808856010437
# Experiment:10
# Metric: {'Precision': 0.04, 'Recall': 0.02, 'Coverage': 38.11, 'Popularity': 0.896725}
# Func worker, run time:15.380778312683105
# Average Result (M=10, K=0, N=10):{'Precision': 0.037, 'Recall': 0.018, 'Coverage': 38.266, 'Popularity': 0.8936807}
# Func run, run time:252.23311924934387

# %%
# 2、MostPopular算法测试
M, N = 10, 20
K = 0
random_exp = Experiment(M, K, N, rt = 'MostPopular')
random_exp.run()
# Out:
# Func loadUserCFData, run time:0.6481475830078125
# Func splitData, run time:9.399346828460693
# Experiment:1
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.704169273376465
# Func splitData, run time:9.341788291931152
# Experiment:2
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.621285676956177
# Func splitData, run time:9.282142162322998
# Experiment:3
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.534503936767578
# Func splitData, run time:9.325172901153564
# Experiment:4
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.76575255393982
# Func splitData, run time:9.440594673156738
# Experiment:5
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.54814338684082
# Func splitData, run time:9.308867692947388
# Experiment:6
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.706859827041626
# Func splitData, run time:9.354121923446655
# Experiment:7
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.659711837768555
# Func splitData, run time:9.31823444366455
# Experiment:8
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.766713619232178
# Func splitData, run time:9.390630960464478
# Experiment:9
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.737923622131348
# Func splitData, run time:9.272279500961304
# Experiment:10
# Metric: {'Precision': 0.36, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func worker, run time:8.78175973892212
# Average Result (M=10, K=0, N=20):{'Precision': 0.35999999999999993, 'Recall': 0.31, 'Coverage': 0.33, 'Popularity': 3.199876}
# Func run, run time:180.9141550064087

# %%
# 3、UserCF算法测试
M, N = 10, 20
for K in [5, 10, 20, 40, 80, 100]:
    random_exp = Experiment(M, K, N, rt = 'UserCF')
    random_exp.run()
# Out:
# Func loadUserCFData, run time:0.6595973968505859
# Func splitData, run time:9.211907625198364
# Experiment:1
# Metric: {'Precision': 1.08, 'Recall': 0.53, 'Coverage': 24.97, 'Popularity': 1.453336}
# Func worker, run time:0.44588446617126465
# Func splitData, run time:9.149270057678223
# Experiment:2
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.96, 'Popularity': 1.453789}
# Func worker, run time:0.45723485946655273
# Func splitData, run time:9.180076837539673
# Experiment:3
# Metric: {'Precision': 1.08, 'Recall': 0.53, 'Coverage': 24.95, 'Popularity': 1.453151}
# Func worker, run time:0.4530761241912842
# Func splitData, run time:9.136667490005493
# Experiment:4
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.96, 'Popularity': 1.453553}
# Func worker, run time:0.4518008232116699
# Func splitData, run time:9.266833305358887
# Experiment:5
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.95, 'Popularity': 1.453239}
# Func worker, run time:0.44895076751708984
# Func splitData, run time:9.729456424713135
# Experiment:6
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.97, 'Popularity': 1.453728}
# Func worker, run time:0.5026347637176514
# Func splitData, run time:9.212161779403687
# Experiment:7
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.95, 'Popularity': 1.453341}
# Func worker, run time:0.41459083557128906
# Func splitData, run time:9.28464651107788
# Experiment:8
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.97, 'Popularity': 1.453789}
# Func worker, run time:0.4607827663421631
# Func splitData, run time:9.354418754577637
# Experiment:9
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.94, 'Popularity': 1.453934}
# Func worker, run time:0.4436948299407959
# Func splitData, run time:9.220764636993408
# Experiment:10
# Metric: {'Precision': 1.09, 'Recall': 0.53, 'Coverage': 24.96, 'Popularity': 1.454012}
# Func worker, run time:0.4335958957672119
# Average Result (M=10, K=5, N=20):{'Precision': 1.0879999999999999, 'Recall': 0.5300000000000001, 'Coverage': 24.958, 'Popularity': 1.4535872}
# Func run, run time:97.92981791496277
# Func loadUserCFData, run time:0.6024658679962158
# Func splitData, run time:9.10874319076538
# Experiment:1
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.2, 'Popularity': 1.529854}
# Func worker, run time:0.7243287563323975
# Func splitData, run time:9.144088745117188
# Experiment:2
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.22, 'Popularity': 1.529873}
# Func worker, run time:0.7546634674072266
# Func splitData, run time:9.145874977111816
# Experiment:3
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.2, 'Popularity': 1.529635}
# Func worker, run time:0.7606663703918457
# Func splitData, run time:9.209272146224976
# Experiment:4
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.21, 'Popularity': 1.52987}
# Func worker, run time:0.7472119331359863
# Func splitData, run time:9.21628451347351
# Experiment:5
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.19, 'Popularity': 1.529844}
# Func worker, run time:0.7566752433776855
# Func splitData, run time:9.22722601890564
# Experiment:6
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.22, 'Popularity': 1.530013}
# Func worker, run time:0.7563126087188721
# Func splitData, run time:9.329188346862793
# Experiment:7
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.19, 'Popularity': 1.529831}
# Func worker, run time:0.757082462310791
# Func splitData, run time:9.239973068237305
# Experiment:8
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.21, 'Popularity': 1.529884}
# Func worker, run time:0.740828275680542
# Func splitData, run time:9.2892324924469
# Experiment:9
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.2, 'Popularity': 1.5298}
# Func worker, run time:0.7362861633300781
# Func splitData, run time:9.162399053573608
# Experiment:10
# Metric: {'Precision': 1.1, 'Recall': 0.65, 'Coverage': 26.21, 'Popularity': 1.530289}
# Func worker, run time:0.7717292308807373
# Average Result (M=10, K=10, N=20):{'Precision': 1.0999999999999999, 'Recall': 0.6500000000000001, 'Coverage': 26.205000000000002, 'Popularity': 1.5298892999999998}
# Func run, run time:100.19155883789062
# Func loadUserCFData, run time:0.6297643184661865
# Func splitData, run time:9.037662744522095
# Experiment:1
# Metric: {'Precision': 1.15, 'Recall': 0.73, 'Coverage': 26.08, 'Popularity': 1.630998}
# Func worker, run time:1.1556503772735596
# Func splitData, run time:9.125890731811523
# Experiment:2
# Metric: {'Precision': 1.14, 'Recall': 0.73, 'Coverage': 26.07, 'Popularity': 1.631529}
# Func worker, run time:1.18068265914917
# Func splitData, run time:8.99318814277649
# Experiment:3
# Metric: {'Precision': 1.15, 'Recall': 0.73, 'Coverage': 26.08, 'Popularity': 1.630828}
# Func worker, run time:1.1831324100494385
# Func splitData, run time:9.161108493804932
# Experiment:4
# Metric: {'Precision': 1.14, 'Recall': 0.73, 'Coverage': 26.07, 'Popularity': 1.631391}
# Func worker, run time:1.1797683238983154
# Func splitData, run time:9.081711292266846
# Experiment:5
# Metric: {'Precision': 1.15, 'Recall': 0.73, 'Coverage': 26.06, 'Popularity': 1.630875}
# Func worker, run time:1.0969345569610596
# Func splitData, run time:9.140058517456055
# Experiment:6
# Metric: {'Precision': 1.14, 'Recall': 0.73, 'Coverage': 26.07, 'Popularity': 1.631717}
# Func worker, run time:1.1482384204864502
# Func splitData, run time:9.097685813903809
# Experiment:7
# Metric: {'Precision': 1.15, 'Recall': 0.73, 'Coverage': 26.06, 'Popularity': 1.631064}
# Func worker, run time:1.1717233657836914
# Func splitData, run time:9.036217212677002
# Experiment:8
# Metric: {'Precision': 1.14, 'Recall': 0.73, 'Coverage': 26.07, 'Popularity': 1.631495}
# Func worker, run time:1.1250698566436768
# Func splitData, run time:9.044328689575195
# Experiment:9
# Metric: {'Precision': 1.15, 'Recall': 0.73, 'Coverage': 26.06, 'Popularity': 1.631229}
# Func worker, run time:1.144655704498291
# Func splitData, run time:9.133539915084839
# Experiment:10
# Metric: {'Precision': 1.14, 'Recall': 0.73, 'Coverage': 26.07, 'Popularity': 1.631633}
# Func worker, run time:1.1716880798339844
# Average Result (M=10, K=20, N=20):{'Precision': 1.145, 'Recall': 0.7300000000000001, 'Coverage': 26.069, 'Popularity': 1.6312759}
# Func run, run time:103.04078221321106
# Func loadUserCFData, run time:0.6083574295043945
# Func splitData, run time:9.224687099456787
# Experiment:1
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.31, 'Popularity': 1.714211}
# Func worker, run time:1.700225591659546
# Func splitData, run time:9.133457899093628
# Experiment:2
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.32, 'Popularity': 1.714557}
# Func worker, run time:1.6371772289276123
# Func splitData, run time:9.131282567977905
# Experiment:3
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.3, 'Popularity': 1.714047}
# Func worker, run time:1.6688470840454102
# Func splitData, run time:9.161977529525757
# Experiment:4
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.32, 'Popularity': 1.714518}
# Func worker, run time:1.679802417755127
# Func splitData, run time:9.324349880218506
# Experiment:5
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.29, 'Popularity': 1.714255}
# Func worker, run time:1.6596856117248535
# Func splitData, run time:9.22107458114624
# Experiment:6
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.32, 'Popularity': 1.714738}
# Func worker, run time:1.650116205215454
# Func splitData, run time:9.250719785690308
# Experiment:7
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.28, 'Popularity': 1.714275}
# Func worker, run time:1.725278615951538
# Func splitData, run time:9.24698281288147
# Experiment:8
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.32, 'Popularity': 1.714618}
# Func worker, run time:1.6642472743988037
# Func splitData, run time:9.237790822982788
# Experiment:9
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.28, 'Popularity': 1.714353}
# Func worker, run time:1.6237754821777344
# Func splitData, run time:9.31595754623413
# Experiment:10
# Metric: {'Precision': 1.18, 'Recall': 0.78, 'Coverage': 25.32, 'Popularity': 1.714658}
# Func worker, run time:1.6925666332244873
# Average Result (M=10, K=40, N=20):{'Precision': 1.18, 'Recall': 0.7800000000000001, 'Coverage': 25.305999999999997, 'Popularity': 1.714423}
# Func run, run time:109.57395625114441
# Func loadUserCFData, run time:0.6144301891326904
# Func splitData, run time:9.064909934997559
# Experiment:1
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.86, 'Popularity': 1.768224}
# Func worker, run time:2.248823642730713
# Func splitData, run time:9.242717742919922
# Experiment:2
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.87, 'Popularity': 1.768568}
# Func worker, run time:2.2104485034942627
# Func splitData, run time:9.1563081741333
# Experiment:3
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.86, 'Popularity': 1.768061}
# Func worker, run time:2.235346794128418
# Func splitData, run time:9.08995246887207
# Experiment:4
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.87, 'Popularity': 1.768529}
# Func worker, run time:2.2461252212524414
# Func splitData, run time:9.236117601394653
# Experiment:5
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.84, 'Popularity': 1.768268}
# Func worker, run time:2.2602996826171875
# Func splitData, run time:9.368227481842041
# Experiment:6
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.87, 'Popularity': 1.768748}
# Func worker, run time:2.2469253540039062
# Func splitData, run time:9.262649059295654
# Experiment:7
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.84, 'Popularity': 1.768287}
# Func worker, run time:2.305551052093506
# Func splitData, run time:9.271846771240234
# Experiment:8
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.87, 'Popularity': 1.768629}
# Func worker, run time:2.3092265129089355
# Func splitData, run time:9.791738510131836
# Experiment:9
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.84, 'Popularity': 1.768365}
# Func worker, run time:2.3105146884918213
# Func splitData, run time:10.170987367630005
# Experiment:10
# Metric: {'Precision': 1.17, 'Recall': 0.78, 'Coverage': 24.87, 'Popularity': 1.768669}
# Func worker, run time:2.9807095527648926
# Average Result (M=10, K=80, N=20):{'Precision': 1.17, 'Recall': 0.7800000000000001, 'Coverage': 24.859, 'Popularity': 1.7684348}
# Func run, run time:117.63238143920898
# Func loadUserCFData, run time:0.6405775547027588
# Func splitData, run time:9.839453935623169
# Experiment:1
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.85, 'Popularity': 1.77307}
# Func worker, run time:2.4796085357666016
# Func splitData, run time:9.490218162536621
# Experiment:2
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.86, 'Popularity': 1.773414}
# Func worker, run time:2.5444939136505127
# Func splitData, run time:9.655776262283325
# Experiment:3
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.84, 'Popularity': 1.772907}
# Func worker, run time:2.500150203704834
# Func splitData, run time:9.67546558380127
# Experiment:4
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.86, 'Popularity': 1.773375}
# Func worker, run time:2.5287246704101562
# Func splitData, run time:9.55608320236206
# Experiment:5
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.83, 'Popularity': 1.773114}
# Func worker, run time:2.51605224609375
# Func splitData, run time:9.484776496887207
# Experiment:6
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.86, 'Popularity': 1.773595}
# Func worker, run time:2.536073923110962
# Func splitData, run time:9.462303638458252
# Experiment:7
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.82, 'Popularity': 1.773134}
# Func worker, run time:2.556030035018921
# Func splitData, run time:9.642435789108276
# Experiment:8
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.86, 'Popularity': 1.773475}
# Func worker, run time:2.485454797744751
# Func splitData, run time:9.077490091323853
# Experiment:9
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.82, 'Popularity': 1.773212}
# Func worker, run time:2.3583381175994873
# Func splitData, run time:9.257863759994507
# Experiment:10
# Metric: {'Precision': 1.19, 'Recall': 0.79, 'Coverage': 24.86, 'Popularity': 1.773515}
# Func worker, run time:2.488766670227051
# Average Result (M=10, K=100, N=20):{'Precision': 1.1899999999999997, 'Recall': 0.79, 'Coverage': 24.845999999999997, 'Popularity': 1.7732810999999997}
# Func run, run time:120.78412508964539

# %%
# 4、ItemCF 算法测试
M, N = 10, 20
for K in [5, 10, 20, 40, 80, 100]:
    random_exp = Experiment(M, K, N, rt = 'ItemCF')
    random_exp.run()
# Out:
# Func loadUserCFData, run time:0.6899688243865967
# Func splitData, run time:9.125893354415894
# Experiment:1
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12716\3547902336.py in <module>
#       3 for K in [5, 10, 20, 40, 80, 100]:
#       4     random_exp = Experiment(M, K, N, rt = 'ItemCF')
# ----> 5     random_exp.run()
#
# ~\AppData\Local\Temp\ipykernel_12716\981407813.py in wrapper(*args, **kwargs)
#       8     def wrapper(*args, **kwargs):
#       9         start_time = time.time()
# ---> 10         res = func(*args, **kwargs)
#      11         stop_time = time.time()
#      12         print('Func %s, run time:%s' % (func.__name__, stop_time - start_time))
#
# ~\AppData\Local\Temp\ipykernel_12716\1052653530.py in run(self)
#      41
#      42             print("Experiment:{}".format(ii + 1))
# ---> 43             metric = self.worker(train, test)
#      44             metrics = {k: metrics[k] + metric[k] for k in metrics}
#      45         metrics = {k: metrics[k] / self.M for k in metrics}
#
# ~\AppData\Local\Temp\ipykernel_12716\981407813.py in wrapper(*args, **kwargs)
#       8     def wrapper(*args, **kwargs):
#       9         start_time = time.time()
# ---> 10         res = func(*args, **kwargs)
#      11         stop_time = time.time()
#      12         print('Func %s, run time:%s' % (func.__name__, stop_time - start_time))
#
# ~\AppData\Local\Temp\ipykernel_12716\1052653530.py in worker(self, train, test)
#      20     @timmer
#      21     def worker(self, train, test):
# ---> 22         getRecs = self.alg[self.rt](train, test, self.K, self.N)
#      23         self.recs = getRecs
#      24         metric = Metric(train, test, getRecs)
#
# ~\AppData\Local\Temp\ipykernel_12716\1120333633.py in ItemCF(train, test, K, N)
#     202
#     203     # 按照相似度排序
# --> 204     sorted_item_sim = {k: list(sorted(v.items(), \
#     205                                key=lambda x: x[1], reverse=True)) \
#     206                        for k, v in sim.items()}
#
# MemoryError:
